# %% [markdown]
# # Mapbox with provinces

# %% [markdown]
# FROM Choropleth Map CSR, want to normalize the date for different bubble sizes and eventually add a slider
#
# Damascus           7069
#
# Aleppo            27629
#
# Rural Damascus    28514
#
# Homs              15329
#
# Hama               9690
#
# Lattakia           3105
#
# Idleb             15670
#
# Al-Hasakeh         1339
#
# Deir-ez-Zor        8914
#
# Tartous            3670
#
# Ar-Raqqa           2727
#
# Dar'a             11931
#
# As-Sweida           995
#
# Quneitra            966

# %%
# reference: https://plot.ly/python/scattermapbox/

import plotly
import plotly.plotly as py
import plotly.graph_objs as go

plotly.tools.set_credentials_file(username='mwirtz', api_key='OyJPg75BEGmqGjXv3LCG')

mapbox_access_token = 'pk.eyJ1IjoibWF0dGhld2lydHoiLCJhIjoiY2p3ZTNpNXlnMHYxcjQ5bzdwMjc0anlpeSJ9.bSLA-SSqEomk0hC52rNliQ'

data = [
    go.Scattermapbox(
        lat=['33.5138'],
        lon=['36.2765'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Damascus'],
    ),
    
    go.Scattermapbox(
        lat=['36.2021'],
        lon=['37.1343'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Aleppo'],
    ),
    
    go.Scattermapbox(
        lat=['33.5167'],
        lon=['36.9541'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Rural Damascus'],
    ),
    
        go.Scattermapbox(
        lat=['34.7324'],
        lon=['36.7137'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Homs'],
    ),
    
    go.Scattermapbox(
        lat=['35.1409'],
        lon=['36.7552'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Hama'],
    ),
    
    go.Scattermapbox(
        lat=['35.5407'],
        lon=['35.7953'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Lattakia'],
    ),
    
    go.Scattermapbox(
        lat=['35.9310'],
        lon=['36.6418'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Idlib'],
    ),
    
    go.Scattermapbox(
        lat=['36.5079'],
        lon=['40.7463'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Al Hasakah'],
    ),
    
    go.Scattermapbox(
        lat=['35.3297'],
        lon=['40.1350'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Deir ez-Zur'],
    ),
    
    go.Scattermapbox(
        lat=['34.8959'],
        lon=['35.8867'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Tartus'],
    ),
    
    go.Scattermapbox(
        lat=['35.9594'],
        lon=['38.9981'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Ar Raqqah'],
    ),
    
    go.Scattermapbox(
        lat=['32.6264'],
        lon=['36.1033'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Daraa'],
    ),
    
    go.Scattermapbox(
        lat=['32.7129'],
        lon=['36.5663'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['As Suwayda'],
    ),
    
    go.Scattermapbox(
        lat=['33.1219'],
        lon=['35.8209'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Quneitra'],
    ),
    
]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=go.layout.Mapbox(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=35,
            lon=37
        ),
        pitch=0,
        zoom=4
    ),
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Syria Mapbox')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mwirtz/14.embed" height="525px" width="100%"></iframe>
