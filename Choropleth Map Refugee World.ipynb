# %% [markdown]
# ## What I was Thinking

# %% [markdown]
# ```2011-2018_monthly_refugee.csv``` contains data about the number of refugees taking shelter in what countries in what year. I was thinking of displaying a world map and depending on the number of refugees seen in the country in each, color each country accordingly. Somewhere down the line, we should add a scroll that allows the user to change the year and see the data change chronologically.

# %% [markdown]
# ## What I Think Needs to be Done

# %% [markdown]
# Here is a tutorial for the plotly library: https://plot.ly/python/choropleth-maps/<br>
# Here is a tutorial for creating a slider using plotly: https://plot.ly/python/gapminder-example/

# %% [markdown]
# If we do a world map, it would be better to use plotly since it has a world map already set for you. However, we need the country code to connect the map and the data in the csv, so... I don't really know what to do... Maybe Geopandas will actually be easier...

# %% [markdown]
# But if we do decide on plotly, we need to
# 1. find the country code and assign all rows a country code corresponding to the country
#     1. https://www.kaggle.com/shep312/plotlycountrycodes
# 2. do some data wrangling and change some country names
#     1. some country names have extra notes in the end, which we should delete
# 3. some values are represented with <b>*</b>, which means the data is confidential; those should be set to 0

# %% [markdown]
# ## Some Things that Still Needs to be Done

# %% [markdown]
# 1. Get rid of "trace 0" when hovering over countries
# 2. Maybe make the lines not hoverable since I can't hover over any European countries and have their country name displayed
#     1. the lines are too dense over Europe
# 3. I decided against having endpoints of lines display something since it'll just display the country name again.

# %% [markdown]
# ## Relevant Libraries

# %%
# import plotly.plotly as py
# from plotly.grid_objs import Grid, Column
# from plotly.tools import FigureFactory as FF 

import pandas as pd
import time
import re
import numpy as np

# %%
refugee_df = pd.read_csv('2011-2018_monthly_refugee.csv')
# refugee_df

# %%
# displays list of unique country names in the data frame
# refugee_df['Country / territory of asylum/residence'].unique()

# %% [markdown]
# Replace:
# 1. Czech Rep. --> Czech Republic
# 2. United Kingdom of Great Britain and Northern Ireland --> ??? (currently United Kingdom)
# 3. Rep. of Korea --> Korea, South
# 4. The former Yugoslav Rep. of Macedonia --> Macedonia
# 5. USA (INS/DHS) --> United States
# 6. USA (EOIR) --> United States
# 7. Serbia and Kosovo: S/RES/1244 (1999) --> Serbia

# %%
code_df = pd.read_csv('plotly_countries_and_codes.csv')
# code_df

# %%
locations_df = pd.read_csv('countries.csv')
# locations_df

# %%
# displays list of unique country names in the data frame
# code_df['COUNTRY'].unique()

# %%
# replacing values in refugee_df dataframe
new_refugee_df = refugee_df.replace({
    'Czech Rep.': 'Czech Republic',
    'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
    'Rep. of Korea': 'Korea, South',
    'The former Yugoslav Rep. of Macedonia': 'Macedonia',
    'USA (INS/DHS)': 'United States',
    'USA (EOIR)': 'United States',
    'Serbia and Kosovo: S/RES/1244 (1999)': 'Serbia'
})
# new_refugee_df

# %%
# joining two tables together
merged_df = new_refugee_df.set_index('Country / territory of asylum/residence').join(code_df.set_index('COUNTRY'))
merged_df = merged_df.reset_index()
# merged_df

# %%
# rename index column to 'Country'
merged_df.rename(columns={'index': 'Country'}, inplace=True)

# remove * and convert values to int values
merged_df['Value'] = merged_df['Value'].apply(lambda x : 0 if x == '*' else int(x))

# sum values and group each country by year
total_df = pd.DataFrame(merged_df.groupby(['Country','Year','CODE']).agg({'Value':np.sum})).reset_index()
# type(total_df)
# total_df

# %% [markdown]
# ## Plotly

# %% [markdown]
# Need to make a plotly account and generate an api key

# %%
import plotly
import plotly.plotly as py
import plotly.offline as pyo
import plotly.graph_objs as go
plotly.__version__

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

plotly.tools.set_credentials_file(username='hwu43', api_key='8d3oItgJtnwYVfSQR7nL')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# # Add longitude and latitude values
# total_df = total_df.set_index('Country').join(locations_df.set_index('name'))
# total_df = total_df.reset_index()

# # rename index column to 'Country'
# total_df.rename(columns={'index': 'Country'}, inplace=True)

# # drop 'country' column which is the same as 'CODE'
# total_df = total_df.drop(columns=['country'], index=1)
# total_df

# %%
# from pandas.api.types import is_string_dtype
# from pandas.api.types import is_numeric_dtype
# # check type of latitude and longitude
# is_numeric_dtype(total_df['latitude'])

# %%
# find the total, just for reference/filler; not to be used in the final visualization
new_total_df = total_df.groupby(['Country', 'CODE']).sum()
new_total_df = new_total_df.reset_index()
# new_total_df
# Out:
#                    Country CODE   Year   Value
# 0                  Albania  ALB  14105    2103
# 1                Australia  AUS  16116     719
# 2                  Austria  AUT  16116   53865
# 3                  Belgium  BEL  16116   23998
# 4   Bosnia and Herzegovina  BIH  14105     333
# 5                 Bulgaria  BGR  16116   20986
# 6                   Canada  CAN  16116    4748
# 7                  Croatia  HRV  16116    1068
# 8                   Cyprus  CYP  16116    6972
# 9           Czech Republic  CZE  16116     508
# 10                 Denmark  DNK  16116   21483
# 11                 Estonia  EST  10072      42
# 12                 Finland  FIN  16116    2887
# 13                  France  FRA  16116   22847
# 14                 Germany  DEU  16116  553257
# 15                  Greece  GRC  16116   58376
# 16                 Hungary  HUN  16116   77362
# 17                 Iceland  ISL  16116     121
# 18                 Ireland  IRL  16116    1250
# 19                   Italy  ITA  16116    5846
# 20                   Japan  JPN  16116      74
# 21            Korea, South  KOR  16116    1358
# 22                  Latvia  LVA  16116     373
# 23           Liechtenstein  LIE  14105      21
# 24               Lithuania  LTU  16116     438
# 25              Luxembourg  LUX  16116    1594
# 26               Macedonia  MKD  16116    2326
# 27                   Malta  MLT  16116    2353
# 28              Montenegro  MNE  16116    4172
# 29             Netherlands  NLD  16116   38005
# 30             New Zealand  NZL  16116      59
# 31                  Norway  NOR  16116   15756
# 32                  Poland  POL  16116     840
# 33                Portugal  PRT  12087    1043
# 34                 Romania  ROU  16116    4194
# 35                  Serbia  SRB  16116   12032
# 36                Slovakia  SVK  16116      79
# 37                Slovenia  SVN  16116     687
# 38                   Spain  ESP  16116   17831
# 39                  Sweden  SWE  16116  117364
# 40             Switzerland  CHE  16116   16954
# 41                  Turkey  TUR  16116    8831
# 42          United Kingdom  GBR  16116   11978
# 43           United States  USA  16116    6967

# %%
# merged_df = new_refugee_df.set_index('Country / territory of asylum/residence').join(code_df.set_index('COUNTRY'))
all_code_df = new_total_df.set_index('CODE').join(code_df.set_index('CODE'))
all_code_df = all_code_df.reset_index()
all_code_df
# Out:
#    CODE                 Country   Year   Value                 COUNTRY  \
# 0   ALB                 Albania  14105    2103                 Albania
# 1   AUS               Australia  16116     719               Australia
# 2   AUT                 Austria  16116   53865                 Austria
# 3   BEL                 Belgium  16116   23998                 Belgium
# 4   BGR                Bulgaria  16116   20986                Bulgaria
# 5   BIH  Bosnia and Herzegovina  14105     333  Bosnia and Herzegovina
# 6   CAN                  Canada  16116    4748                  Canada
# 7   CHE             Switzerland  16116   16954             Switzerland
# 8   CYP                  Cyprus  16116    6972                  Cyprus
# 9   CZE          Czech Republic  16116     508          Czech Republic
# 10  DEU                 Germany  16116  553257                 Germany
# 11  DNK                 Denmark  16116   21483                 Denmark
# 12  ESP                   Spain  16116   17831                   Spain
# 13  EST                 Estonia  10072      42                 Estonia
# 14  FIN                 Finland  16116    2887                 Finland
# 15  FRA                  France  16116   22847                  France
# 16  GBR          United Kingdom  16116   11978          United Kingdom
# 17  GRC                  Greece  16116   58376                  Greece
# 18  HRV                 Croatia  16116    1068                 Croatia
# 19  HUN                 Hungary  16116   77362                 Hungary
# 20  IRL                 Ireland  16116    1250                 Ireland
# 21  ISL                 Iceland  16116     121                 Iceland
# 22  ITA                   Italy  16116    5846                   Italy
# 23  JPN                   Japan  16116      74                   Japan
# 24  KOR            Korea, South  16116    1358            Korea, South
# 25  LIE           Liechtenstein  14105      21           Liechtenstein
# 26  LTU               Lithuania  16116     438               Lithuania
# 27  LUX              Luxembourg  16116    1594              Luxembourg
# 28  LVA                  Latvia  16116     373                  Latvia
# 29  MKD               Macedonia  16116    2326               Macedonia
# 30  MLT                   Malta  16116    2353                   Malta
# 31  MNE              Montenegro  16116    4172              Montenegro
# 32  NLD             Netherlands  16116   38005             Netherlands
# 33  NOR                  Norway  16116   15756                  Norway
# 34  NZL             New Zealand  16116      59             New Zealand
# 35  POL                  Poland  16116     840                  Poland
# 36  PRT                Portugal  12087    1043                Portugal
# 37  ROU                 Romania  16116    4194                 Romania
# 38  SRB                  Serbia  16116   12032                  Serbia
# 39  SVK                Slovakia  16116      79                Slovakia
# 40  SVN                Slovenia  16116     687                Slovenia
# 41  SWE                  Sweden  16116  117364                  Sweden
# 42  TUR                  Turkey  16116    8831                  Turkey
# 43  USA           United States  16116    6967           United States
#
#     GDP (BILLIONS)
# 0            13.40
# 1          1483.00
# 2           436.10
# 3           527.80
# 4            55.08
# 5            19.55
# 6          1794.00
# 7           679.00
# 8            21.34
# 9           205.60
# 10         3820.00
# 11          347.20
# 12         1400.00
# 13           26.36
# 14          276.30
# 15         2902.00
# 16         2848.00
# 17          246.40
# 18           57.18
# 19          129.70
# 20          245.80
# 21           16.20
# 22         2129.00
# 23         4770.00
# 24         1410.00
# 25            5.11
# 26           48.72
# 27           63.93
# 28           32.82
# 29           10.92
# 30           10.57
# 31            4.66
# 32          880.40
# 33          511.60
# 34          201.00
# 35          552.20
# 36          228.20
# 37          199.00
# 38           42.65
# 39           99.75
# 40           49.93
# 41          559.10
# 42          813.30
# 43        17420.00

# %%
# Add longitude and latitude values
all_code_df = all_code_df.set_index('Country').join(locations_df.set_index('name'))
all_code_df = all_code_df.reset_index()

# rename index column to 'Country'
all_code_df.rename(columns={'index': 'Country'}, inplace=True)

# # drop 'country' column which is the same as 'CODE'
# all_code_df = all_code_df.drop(columns=['COUNTRY','country'], index=1)
# all_code_df
# Out:
#                    Country CODE   Year   Value                 COUNTRY  \
# 0                  Albania  ALB  14105    2103                 Albania
# 1                Australia  AUS  16116     719               Australia
# 2                  Austria  AUT  16116   53865                 Austria
# 3                  Belgium  BEL  16116   23998                 Belgium
# 4                 Bulgaria  BGR  16116   20986                Bulgaria
# 5   Bosnia and Herzegovina  BIH  14105     333  Bosnia and Herzegovina
# 6                   Canada  CAN  16116    4748                  Canada
# 7              Switzerland  CHE  16116   16954             Switzerland
# 8                   Cyprus  CYP  16116    6972                  Cyprus
# 9           Czech Republic  CZE  16116     508          Czech Republic
# 10                 Germany  DEU  16116  553257                 Germany
# 11                 Denmark  DNK  16116   21483                 Denmark
# 12                   Spain  ESP  16116   17831                   Spain
# 13                 Estonia  EST  10072      42                 Estonia
# 14                 Finland  FIN  16116    2887                 Finland
# 15                  France  FRA  16116   22847                  France
# 16          United Kingdom  GBR  16116   11978          United Kingdom
# 17                  Greece  GRC  16116   58376                  Greece
# 18                 Croatia  HRV  16116    1068                 Croatia
# 19                 Hungary  HUN  16116   77362                 Hungary
# 20                 Ireland  IRL  16116    1250                 Ireland
# 21                 Iceland  ISL  16116     121                 Iceland
# 22                   Italy  ITA  16116    5846                   Italy
# 23                   Japan  JPN  16116      74                   Japan
# 24            Korea, South  KOR  16116    1358            Korea, South
# 25           Liechtenstein  LIE  14105      21           Liechtenstein
# 26               Lithuania  LTU  16116     438               Lithuania
# 27              Luxembourg  LUX  16116    1594              Luxembourg
# 28                  Latvia  LVA  16116     373                  Latvia
# 29               Macedonia  MKD  16116    2326               Macedonia
# 30                   Malta  MLT  16116    2353                   Malta
# 31              Montenegro  MNE  16116    4172              Montenegro
# 32             Netherlands  NLD  16116   38005             Netherlands
# 33                  Norway  NOR  16116   15756                  Norway
# 34             New Zealand  NZL  16116      59             New Zealand
# 35                  Poland  POL  16116     840                  Poland
# 36                Portugal  PRT  12087    1043                Portugal
# 37                 Romania  ROU  16116    4194                 Romania
# 38                  Serbia  SRB  16116   12032                  Serbia
# 39                Slovakia  SVK  16116      79                Slovakia
# 40                Slovenia  SVN  16116     687                Slovenia
# 41                  Sweden  SWE  16116  117364                  Sweden
# 42                  Turkey  TUR  16116    8831                  Turkey
# 43           United States  USA  16116    6967           United States
#
#     GDP (BILLIONS) country   latitude   longitude
# 0            13.40      AL  41.153332   20.168331
# 1          1483.00      AU -25.274398  133.775136
# 2           436.10      AT  47.516231   14.550072
# 3           527.80      BE  50.503887    4.469936
# 4            55.08      BG  42.733883   25.485830
# 5            19.55      BA  43.915886   17.679076
# 6          1794.00      CA  56.130366 -106.346771
# 7           679.00      CH  46.818188    8.227512
# 8            21.34      CY  35.126413   33.429859
# 9           205.60      CZ  49.817492   15.472962
# 10         3820.00      DE  51.165691   10.451526
# 11          347.20      DK  56.263920    9.501785
# 12         1400.00      ES  40.463667   -3.749220
# 13           26.36      EE  58.595272   25.013607
# 14          276.30      FI  61.924110   25.748151
# 15         2902.00      FR  46.227638    2.213749
# 16         2848.00      GB  55.378051   -3.435973
# 17          246.40      GR  39.074208   21.824312
# 18           57.18      HR  45.100000   15.200000
# 19          129.70      HU  47.162494   19.503304
# 20          245.80      IE  53.412910   -8.243890
# 21           16.20      IS  64.963051  -19.020835
# 22         2129.00      IT  41.871940   12.567380
# 23         4770.00      JP  36.204824  138.252924
# 24         1410.00     NaN        NaN         NaN
# 25            5.11      LI  47.166000    9.555373
# 26           48.72      LT  55.169438   23.881275
# 27           63.93      LU  49.815273    6.129583
# 28           32.82      LV  56.879635   24.603189
# 29           10.92     NaN        NaN         NaN
# 30           10.57      MT  35.937496   14.375416
# 31            4.66      ME  42.708678   19.374390
# 32          880.40      NL  52.132633    5.291266
# 33          511.60      NO  60.472024    8.468946
# 34          201.00      NZ -40.900557  174.885971
# 35          552.20      PL  51.919438   19.145136
# 36          228.20      PT  39.399872   -8.224454
# 37          199.00      RO  45.943161   24.966760
# 38           42.65      RS  44.016521   21.005859
# 39           99.75      SK  48.669026   19.699024
# 40           49.93      SI  46.151241   14.995463
# 41          559.10      SE  60.128161   18.643501
# 42          813.30      TR  38.963745   35.243322
# 43        17420.00      US  37.090240  -95.712891

# %%
# rename Korea, South to South Korea
name_change = {
    'Korea, South': 'South Korea'
}

# renames the provinces using name_change
all_code_df.replace(name_change, inplace=True)
# all_code_df
# Out:
#                    Country CODE   Year   Value                 COUNTRY  \
# 0                  Albania  ALB  14105    2103                 Albania
# 1                Australia  AUS  16116     719               Australia
# 2                  Austria  AUT  16116   53865                 Austria
# 3                  Belgium  BEL  16116   23998                 Belgium
# 4                 Bulgaria  BGR  16116   20986                Bulgaria
# 5   Bosnia and Herzegovina  BIH  14105     333  Bosnia and Herzegovina
# 6                   Canada  CAN  16116    4748                  Canada
# 7              Switzerland  CHE  16116   16954             Switzerland
# 8                   Cyprus  CYP  16116    6972                  Cyprus
# 9           Czech Republic  CZE  16116     508          Czech Republic
# 10                 Germany  DEU  16116  553257                 Germany
# 11                 Denmark  DNK  16116   21483                 Denmark
# 12                   Spain  ESP  16116   17831                   Spain
# 13                 Estonia  EST  10072      42                 Estonia
# 14                 Finland  FIN  16116    2887                 Finland
# 15                  France  FRA  16116   22847                  France
# 16          United Kingdom  GBR  16116   11978          United Kingdom
# 17                  Greece  GRC  16116   58376                  Greece
# 18                 Croatia  HRV  16116    1068                 Croatia
# 19                 Hungary  HUN  16116   77362                 Hungary
# 20                 Ireland  IRL  16116    1250                 Ireland
# 21                 Iceland  ISL  16116     121                 Iceland
# 22                   Italy  ITA  16116    5846                   Italy
# 23                   Japan  JPN  16116      74                   Japan
# 24             South Korea  KOR  16116    1358             South Korea
# 25           Liechtenstein  LIE  14105      21           Liechtenstein
# 26               Lithuania  LTU  16116     438               Lithuania
# 27              Luxembourg  LUX  16116    1594              Luxembourg
# 28                  Latvia  LVA  16116     373                  Latvia
# 29               Macedonia  MKD  16116    2326               Macedonia
# 30                   Malta  MLT  16116    2353                   Malta
# 31              Montenegro  MNE  16116    4172              Montenegro
# 32             Netherlands  NLD  16116   38005             Netherlands
# 33                  Norway  NOR  16116   15756                  Norway
# 34             New Zealand  NZL  16116      59             New Zealand
# 35                  Poland  POL  16116     840                  Poland
# 36                Portugal  PRT  12087    1043                Portugal
# 37                 Romania  ROU  16116    4194                 Romania
# 38                  Serbia  SRB  16116   12032                  Serbia
# 39                Slovakia  SVK  16116      79                Slovakia
# 40                Slovenia  SVN  16116     687                Slovenia
# 41                  Sweden  SWE  16116  117364                  Sweden
# 42                  Turkey  TUR  16116    8831                  Turkey
# 43           United States  USA  16116    6967           United States
#
#     GDP (BILLIONS) country   latitude   longitude
# 0            13.40      AL  41.153332   20.168331
# 1          1483.00      AU -25.274398  133.775136
# 2           436.10      AT  47.516231   14.550072
# 3           527.80      BE  50.503887    4.469936
# 4            55.08      BG  42.733883   25.485830
# 5            19.55      BA  43.915886   17.679076
# 6          1794.00      CA  56.130366 -106.346771
# 7           679.00      CH  46.818188    8.227512
# 8            21.34      CY  35.126413   33.429859
# 9           205.60      CZ  49.817492   15.472962
# 10         3820.00      DE  51.165691   10.451526
# 11          347.20      DK  56.263920    9.501785
# 12         1400.00      ES  40.463667   -3.749220
# 13           26.36      EE  58.595272   25.013607
# 14          276.30      FI  61.924110   25.748151
# 15         2902.00      FR  46.227638    2.213749
# 16         2848.00      GB  55.378051   -3.435973
# 17          246.40      GR  39.074208   21.824312
# 18           57.18      HR  45.100000   15.200000
# 19          129.70      HU  47.162494   19.503304
# 20          245.80      IE  53.412910   -8.243890
# 21           16.20      IS  64.963051  -19.020835
# 22         2129.00      IT  41.871940   12.567380
# 23         4770.00      JP  36.204824  138.252924
# 24         1410.00     NaN        NaN         NaN
# 25            5.11      LI  47.166000    9.555373
# 26           48.72      LT  55.169438   23.881275
# 27           63.93      LU  49.815273    6.129583
# 28           32.82      LV  56.879635   24.603189
# 29           10.92     NaN        NaN         NaN
# 30           10.57      MT  35.937496   14.375416
# 31            4.66      ME  42.708678   19.374390
# 32          880.40      NL  52.132633    5.291266
# 33          511.60      NO  60.472024    8.468946
# 34          201.00      NZ -40.900557  174.885971
# 35          552.20      PL  51.919438   19.145136
# 36          228.20      PT  39.399872   -8.224454
# 37          199.00      RO  45.943161   24.966760
# 38           42.65      RS  44.016521   21.005859
# 39           99.75      SK  48.669026   19.699024
# 40           49.93      SI  46.151241   14.995463
# 41          559.10      SE  60.128161   18.643501
# 42          813.30      TR  38.963745   35.243322
# 43        17420.00      US  37.090240  -95.712891

# %%
# add coordinates for South Korea and Macedonia
all_code_df.at[24, 'latitude'] = 127.7669
all_code_df.at[24, 'longitude'] = 35.9078

all_code_df.at[29, 'latitude'] = 21.7453
all_code_df.at[29, 'longitude'] = 41.6086

# all_code_df
# Out:
#                    Country CODE   Year   Value                 COUNTRY  \
# 0                  Albania  ALB  14105    2103                 Albania
# 1                Australia  AUS  16116     719               Australia
# 2                  Austria  AUT  16116   53865                 Austria
# 3                  Belgium  BEL  16116   23998                 Belgium
# 4                 Bulgaria  BGR  16116   20986                Bulgaria
# 5   Bosnia and Herzegovina  BIH  14105     333  Bosnia and Herzegovina
# 6                   Canada  CAN  16116    4748                  Canada
# 7              Switzerland  CHE  16116   16954             Switzerland
# 8                   Cyprus  CYP  16116    6972                  Cyprus
# 9           Czech Republic  CZE  16116     508          Czech Republic
# 10                 Germany  DEU  16116  553257                 Germany
# 11                 Denmark  DNK  16116   21483                 Denmark
# 12                   Spain  ESP  16116   17831                   Spain
# 13                 Estonia  EST  10072      42                 Estonia
# 14                 Finland  FIN  16116    2887                 Finland
# 15                  France  FRA  16116   22847                  France
# 16          United Kingdom  GBR  16116   11978          United Kingdom
# 17                  Greece  GRC  16116   58376                  Greece
# 18                 Croatia  HRV  16116    1068                 Croatia
# 19                 Hungary  HUN  16116   77362                 Hungary
# 20                 Ireland  IRL  16116    1250                 Ireland
# 21                 Iceland  ISL  16116     121                 Iceland
# 22                   Italy  ITA  16116    5846                   Italy
# 23                   Japan  JPN  16116      74                   Japan
# 24             South Korea  KOR  16116    1358             South Korea
# 25           Liechtenstein  LIE  14105      21           Liechtenstein
# 26               Lithuania  LTU  16116     438               Lithuania
# 27              Luxembourg  LUX  16116    1594              Luxembourg
# 28                  Latvia  LVA  16116     373                  Latvia
# 29               Macedonia  MKD  16116    2326               Macedonia
# 30                   Malta  MLT  16116    2353                   Malta
# 31              Montenegro  MNE  16116    4172              Montenegro
# 32             Netherlands  NLD  16116   38005             Netherlands
# 33                  Norway  NOR  16116   15756                  Norway
# 34             New Zealand  NZL  16116      59             New Zealand
# 35                  Poland  POL  16116     840                  Poland
# 36                Portugal  PRT  12087    1043                Portugal
# 37                 Romania  ROU  16116    4194                 Romania
# 38                  Serbia  SRB  16116   12032                  Serbia
# 39                Slovakia  SVK  16116      79                Slovakia
# 40                Slovenia  SVN  16116     687                Slovenia
# 41                  Sweden  SWE  16116  117364                  Sweden
# 42                  Turkey  TUR  16116    8831                  Turkey
# 43           United States  USA  16116    6967           United States
#
#     GDP (BILLIONS) country    latitude   longitude
# 0            13.40      AL   41.153332   20.168331
# 1          1483.00      AU  -25.274398  133.775136
# 2           436.10      AT   47.516231   14.550072
# 3           527.80      BE   50.503887    4.469936
# 4            55.08      BG   42.733883   25.485830
# 5            19.55      BA   43.915886   17.679076
# 6          1794.00      CA   56.130366 -106.346771
# 7           679.00      CH   46.818188    8.227512
# 8            21.34      CY   35.126413   33.429859
# 9           205.60      CZ   49.817492   15.472962
# 10         3820.00      DE   51.165691   10.451526
# 11          347.20      DK   56.263920    9.501785
# 12         1400.00      ES   40.463667   -3.749220
# 13           26.36      EE   58.595272   25.013607
# 14          276.30      FI   61.924110   25.748151
# 15         2902.00      FR   46.227638    2.213749
# 16         2848.00      GB   55.378051   -3.435973
# 17          246.40      GR   39.074208   21.824312
# 18           57.18      HR   45.100000   15.200000
# 19          129.70      HU   47.162494   19.503304
# 20          245.80      IE   53.412910   -8.243890
# 21           16.20      IS   64.963051  -19.020835
# 22         2129.00      IT   41.871940   12.567380
# 23         4770.00      JP   36.204824  138.252924
# 24         1410.00     NaN  127.766900   35.907800
# 25            5.11      LI   47.166000    9.555373
# 26           48.72      LT   55.169438   23.881275
# 27           63.93      LU   49.815273    6.129583
# 28           32.82      LV   56.879635   24.603189
# 29           10.92     NaN   21.745300   41.608600
# 30           10.57      MT   35.937496   14.375416
# 31            4.66      ME   42.708678   19.374390
# 32          880.40      NL   52.132633    5.291266
# 33          511.60      NO   60.472024    8.468946
# 34          201.00      NZ  -40.900557  174.885971
# 35          552.20      PL   51.919438   19.145136
# 36          228.20      PT   39.399872   -8.224454
# 37          199.00      RO   45.943161   24.966760
# 38           42.65      RS   44.016521   21.005859
# 39           99.75      SK   48.669026   19.699024
# 40           49.93      SI   46.151241   14.995463
# 41          559.10      SE   60.128161   18.643501
# 42          813.30      TR   38.963745   35.243322
# 43        17420.00      US   37.090240  -95.712891

# %%
# was experimenting with removing the "trace 0" when hovering over countries
# removes rows where Country column has nan
dropped_nan_df = all_code_df[pd.notnull(all_code_df['Country'])]
# dropped_nan_df

# %%
# plot out the countries
data = [go.Choropleth(
    locations = all_code_df['CODE'],
    z = all_code_df['Value'],
    text = all_code_df['Country'],
    colorscale = [
        [0, "rgb(51, 0, 25)"],
        [0.3, "rgb(102, 0, 51)"],
        [0.5, "rgb(153, 0, 76)"],
        [0.6, "rgb(204, 0, 102)"],
        [0.7, "rgb(255, 51, 153)"],
        [1, "rgb(255, 153, 204)"]
    ],
    zmin = 0,
    zmax = 600000,
    autocolorscale = False,
    reversescale = True,
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(180,180,180)',
            width = 0.5
        )),
    colorbar = go.choropleth.ColorBar(
        tickprefix = '',
        title = 'Number of Syrian Refugees'),
)]

# following code is for lines connecting countries
countries = [go.Scattergeo(
    lon = dropped_nan_df['longitude'],
    lat = dropped_nan_df['latitude'],
    hoverinfo = 'none',
#     text = dropped_nan_df['COUNTRY'],
    mode = 'none',
#     marker = go.scattergeo.Marker(
#         size = 0,
#         color = 'rgb(255, 0, 0)',
#         line = go.scattergeo.marker.Line(
#             width = 3,
#             color = 'rgba(68, 68, 68, 0)'
#         ))
    )]

refugee_paths = []

syria_start_lon = 33.5138
syria_start_lat = 36.2765
maximum_value = float(dropped_nan_df['Value'].max())

for i in range(len(dropped_nan_df)):
    # setting the opacity of the lines
    opacity = 0
    country_refugee = dropped_nan_df['Value'][i]
    opacity = float(country_refugee) / maximum_value
    # doing this because otherwise, the lines to countries besides Germany are invisible
    if opacity < 0.25:
        opacity = 0.25
        
    refugee_paths.append(
        go.Scattergeo(
            locationmode = 'country names',
            lon = [syria_start_lon, dropped_nan_df['longitude'][i]],
            lat = [syria_start_lat, dropped_nan_df['latitude'][i]],
            mode = 'lines',
            line = go.scattergeo.Line(
                width = 1,
                color = 'red',
            ),
            opacity = opacity,
        )
    )

layout = go.Layout(
    showlegend = False,
    title = go.layout.Title(
        text = '2011-2018 Syrian Refugee Migration Patterns'
    ),
    
    geo = go.layout.Geo(
        showframe = False,
        showcoastlines = False,
        projection = go.layout.geo.Projection(
#             type = 'azimuthal equal area'
            type = 'equirectangular',
        ),
        showland = True,
        landcolor = 'rgb(243, 243, 243)',
        countrycolor = 'rgb(204, 204, 204)', 
    ),
    
    annotations = [go.layout.Annotation(
        x = 0.55,
        y = 0.1,
        xref = 'paper',
        yref = 'paper',
        text = 'Source: <a href="http://popstats.unhcr.org/en/asylum_seekers_monthly">\
            Asylum-Seekers (Monthly Data)</a>',
        showarrow = False
    )]
)

fig = go.Figure(data = data + refugee_paths + countries, layout = layout)
py.iplot(fig, validate = False, filename = 'd3-world-map')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~hwu43/0 or inside your plot.ly account where it is named 'd3-world-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hwu43/0.embed" height="525px" width="100%"></iframe>
